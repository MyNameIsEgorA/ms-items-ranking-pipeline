# %%
import pandas as pd

# %%
df = pd.read_csv("../data_dumps/categories.csv", sep=";")
df.head()
# Out:
#   CategoryIdsGarageID CategoryIdsInsalesId CategoryIdsKixboxOrderId  \
# 0                 NaN                  NaN                      NaN
# 1                 NaN                  NaN             260760699013
# 2                 NaN                  NaN                      NaN
# 3                 NaN             29656641                      NaN
# 4                 NaN                  NaN                      NaN
#
#    CategoryIdsKixboxReserve CategoryIdsKixboxShopifyId  \
# 0                       NaN               233257435303
# 1                       NaN                        NaN
# 2                       NaN               260760699013
# 3                       NaN                        NaN
# 4                       NaN               183535730821
#
#    CategoryIdsKixboxWebsiteId  CategoryIdsKixboxWebsiteTestId  \
# 0                         NaN                             NaN
# 1                         NaN                             NaN
# 2                         NaN                             NaN
# 3                         NaN                             NaN
# 4                         NaN                             NaN
#
#    CategoryIdsMBOctoberShopify  CategoryIdsTestIrakli  \
# 0                          NaN                    NaN
# 1                          NaN                    NaN
# 2                          NaN                    NaN
# 3                          NaN                    NaN
# 4                          NaN                    NaN
#
#                     CategoryName  CategoryParentCategoryIdsGarageID  \
# 0                          1+1=3                                NaN
# 1                 40S & SHORTIES                                NaN
# 2                 40S & SHORTIES                                NaN
# 3                 40S & SHORTIES                                NaN
# 4  40s & shorties (183535730821)                                NaN
#
#    CategoryParentCategoryIdsInsalesId  CategoryParentCategoryIdsKixboxOrderId  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                          29652522.0                                     NaN
# 4                                 NaN                                     NaN
#
#    CategoryParentCategoryIdsKixboxReserve  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    CategoryParentCategoryIdsKixboxShopifyId  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    CategoryParentCategoryIdsKixboxWebsiteId  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    CategoryParentCategoryIdsKixboxWebsiteTestId  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    CategoryParentCategoryIdsMBOctoberShopify  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    CategoryParentCategoryIdsTestIrakli CategoryParentCategoryName
# 0                                  NaN                        NaN
# 1                                  NaN                        NaN
# 2                                  NaN                        NaN
# 3                                  NaN                     Бренды
# 4                                  NaN                        NaN

# %%
column_names = df.columns.tolist()
column_names, len(column_names)
# Out:
# (['CategoryIdsGarageID',
#   'CategoryIdsInsalesId',
#   'CategoryIdsKixboxOrderId',
#   'CategoryIdsKixboxReserve',
#   'CategoryIdsKixboxShopifyId',
#   'CategoryIdsKixboxWebsiteId',
#   'CategoryIdsKixboxWebsiteTestId',
#   'CategoryIdsMBOctoberShopify',
#   'CategoryIdsTestIrakli',
#   'CategoryName',
#   'CategoryParentCategoryIdsGarageID',
#   'CategoryParentCategoryIdsInsalesId',
#   'CategoryParentCategoryIdsKixboxOrderId',
#   'CategoryParentCategoryIdsKixboxReserve',
#   'CategoryParentCategoryIdsKixboxShopifyId',
#   'CategoryParentCategoryIdsKixboxWebsiteId',
#   'CategoryParentCategoryIdsKixboxWebsiteTestId',
#   'CategoryParentCategoryIdsMBOctoberShopify',
#   'CategoryParentCategoryIdsTestIrakli',
#   'CategoryParentCategoryName'],
#  20)

# %%
df = df.loc[:, df.notna().mean() >= 0.1]

# %%
(df.notnull().mean() * 100).round(2)
# Out:
# CategoryIdsGarageID                              23.79
# CategoryIdsKixboxShopifyId                       14.44
# CategoryIdsKixboxWebsiteId                       27.89
# CategoryIdsKixboxWebsiteTestId                   12.85
# CategoryName                                    100.00
# CategoryParentCategoryIdsKixboxWebsiteId         26.32
# CategoryParentCategoryIdsKixboxWebsiteTestId     10.88
# CategoryParentCategoryName                       50.78
# dtype: float64

# %%
df.nunique()
# Out:
# CategoryIdsGarageID                             1063
# CategoryIdsKixboxShopifyId                       645
# CategoryIdsKixboxWebsiteId                      1246
# CategoryIdsKixboxWebsiteTestId                   574
# CategoryName                                    2375
# CategoryParentCategoryIdsKixboxWebsiteId         268
# CategoryParentCategoryIdsKixboxWebsiteTestId     147
# CategoryParentCategoryName                       201
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(113)

# %%
df = df.drop_duplicates()
len(df)
# Out:
# 4355

# %%
df.to_csv('../cleaned_data/categories.csv')
